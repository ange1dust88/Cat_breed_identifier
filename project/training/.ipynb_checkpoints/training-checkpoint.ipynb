# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNELS = 3

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "Cats",
    shuffle = True,
    image_size  = (IMAGE_SIZE, IMAGE_SIZE),
    batch_size = BATCH_SIZE
    
)
# Out:
# Found 2399 files belonging to 12 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Abyssinian',
#  'Bengal',
#  'Birman',
#  'Bombay',
#  'British_Shorthair',
#  'Egyptian_Mau',
#  'Maine_Coon',
#  'Persian',
#  'Ragdoll',
#  'Russian_blue',
#  'Siamese',
#  'Sphynx']

# %%
plt.figure(figsize=(10,10))
for image_batch, label_batch in dataset.take(1):
    for i in range (12):
        plt.subplot(3,4, i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")

# %%
def get_dataset_partitions_tf(dataset, train_split=0.8, validation_split=0.1, test_split=0.1, shuffle=True, shuffle_size = 10000):
    dataset_size = len (dataset)

    if shuffle:
        dataset = dataset.shuffle(shuffle_size, seed=11)
    train_size = int(train_split * dataset_size)
    validation_size = int(validation_split * dataset_size)
    
    train_dataset = dataset.take(train_size)
    validation_dataset = dataset.skip(train_size).take(validation_size)
    test_dataset = dataset.skip(train_size).skip(validation_size)

    return train_dataset, validation_dataset, test_dataset

# %%
train_dataset,validation_dataset, test_dataset = get_dataset_partitions_tf(dataset)
len(train_dataset)
# Out:
# 60

# %%
train_dataset = train_dataset.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE) 
validation_dataset = validation_dataset.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE) 
test_dataset = test_dataset.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(IMAGE_SIZE, IMAGE_SIZE), 
    layers.Rescaling(1.0 / 255)              
])

# %%
data_argumentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.2)
])

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)

base_model = tf.keras.applications.VGG16(
    input_shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS),
    include_top=False, 
    weights='imagenet'  
)

base_model.trainable = False

model = models.Sequential([
    resize_and_rescale,  
    data_argumentation, 
    base_model,        
    layers.GlobalAveragePooling2D(),  
    layers.Dense(128, activation='relu'),  
    layers.Dropout(0.5), 
    layers.Dense(12, activation='softmax'), 
])

model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)              │ (32, 256, 256, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_1 (Sequential)            │ (32, 256, 256, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ vgg16 (Functional)                   │ (32, 8, 8, 512)             │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_3           │ (32, 512)                   │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (32, 128)                   │          65,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (32, 128)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (32, 12)                    │           1,548 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,781,900 (56.39 MB)
#  Trainable params: 67,212 (262.55 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
model.compile(
    optimizer='adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),  
    metrics=['accuracy'],
)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
EPOCHS = 50

history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=1,
    validation_data=validation_dataset,
    callbacks=[early_stopping]  
)
# Out:
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 376s 6s/step - accuracy: 0.1122 - loss: 2.5352 - val_accuracy: 0.2915 - val_loss: 2.3188
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 340s 6s/step - accuracy: 0.2016 - loss: 2.3372 - val_accuracy: 0.2646 - val_loss: 2.1718
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 326s 5s/step - accuracy: 0.2416 - loss: 2.2040 - val_accuracy: 0.4843 - val_loss: 1.9859
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 315s 5s/step - accuracy: 0.2787 - loss: 2.1079 - val_accuracy: 0.4574 - val_loss: 1.8604
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 315s 5s/step - accuracy: 0.2906 - loss: 2.0060 - val_accuracy: 0.5022 - val_loss: 1.7553
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.3111 - loss: 1.9282 - val_accuracy: 0.5516 - val_loss: 1.6644
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 316s 5s/step - accuracy: 0.3390 - loss: 1.8544 - val_accuracy: 0.5336 - val_loss: 1.6171
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.3453 - loss: 1.8264 - val_accuracy: 0.5471 - val_loss: 1.5612
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.3737 - loss: 1.7789 - val_accuracy: 0.5291 - val_loss: 1.5304
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 315s 5s/step - accuracy: 0.3853 - loss: 1.7318 - val_accuracy: 0.5605 - val_loss: 1.4585
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.4131 - loss: 1.6743 - val_accuracy: 0.5874 - val_loss: 1.4148
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.3918 - loss: 1.7220 - val_accuracy: 0.5830 - val_loss: 1.3842
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.4318 - loss: 1.6314 - val_accuracy: 0.6188 - val_loss: 1.3697
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.4376 - loss: 1.5851 - val_accuracy: 0.5919 - val_loss: 1.3362
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.4359 - loss: 1.5957 - val_accuracy: 0.5830 - val_loss: 1.2946
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.4343 - loss: 1.5617 - val_accuracy: 0.6099 - val_loss: 1.2618
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.4330 - loss: 1.5738 - val_accuracy: 0.6233 - val_loss: 1.2566
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.4281 - loss: 1.5568 - val_accuracy: 0.6009 - val_loss: 1.2065
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.4470 - loss: 1.5370 - val_accuracy: 0.6188 - val_loss: 1.2370
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.4473 - loss: 1.5427 - val_accuracy: 0.6233 - val_loss: 1.2023
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.4916 - loss: 1.4846 - val_accuracy: 0.6188 - val_loss: 1.1730
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.4850 - loss: 1.4748 - val_accuracy: 0.6771 - val_loss: 1.1377
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5016 - loss: 1.4358 - val_accuracy: 0.6816 - val_loss: 1.1340
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.4786 - loss: 1.4608 - val_accuracy: 0.6682 - val_loss: 1.1176
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5055 - loss: 1.4543 - val_accuracy: 0.6413 - val_loss: 1.1126
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5027 - loss: 1.4006 - val_accuracy: 0.6592 - val_loss: 1.1031
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5038 - loss: 1.3803 - val_accuracy: 0.6682 - val_loss: 1.0750
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5113 - loss: 1.3911 - val_accuracy: 0.7220 - val_loss: 1.0454
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5013 - loss: 1.3861 - val_accuracy: 0.6996 - val_loss: 1.0616
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5278 - loss: 1.3487 - val_accuracy: 0.7085 - val_loss: 1.0260
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5250 - loss: 1.3632 - val_accuracy: 0.6726 - val_loss: 1.0212
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 315s 5s/step - accuracy: 0.5082 - loss: 1.3553 - val_accuracy: 0.7085 - val_loss: 0.9944
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5196 - loss: 1.3621 - val_accuracy: 0.7130 - val_loss: 0.9802
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5471 - loss: 1.2901 - val_accuracy: 0.7444 - val_loss: 0.9566
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 316s 5s/step - accuracy: 0.5033 - loss: 1.3769 - val_accuracy: 0.6951 - val_loss: 0.9955
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5702 - loss: 1.2643 - val_accuracy: 0.6861 - val_loss: 0.9935
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5176 - loss: 1.3227 - val_accuracy: 0.6771 - val_loss: 0.9642
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5351 - loss: 1.2995 - val_accuracy: 0.7040 - val_loss: 0.9567
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5525 - loss: 1.2927 - val_accuracy: 0.6906 - val_loss: 0.9553
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5678 - loss: 1.2385 - val_accuracy: 0.7130 - val_loss: 0.9658
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5328 - loss: 1.3107 - val_accuracy: 0.7085 - val_loss: 0.9224
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5674 - loss: 1.2603 - val_accuracy: 0.7220 - val_loss: 0.9209
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5581 - loss: 1.2799 - val_accuracy: 0.7040 - val_loss: 0.9177
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5573 - loss: 1.2636 - val_accuracy: 0.7309 - val_loss: 0.8998
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5457 - loss: 1.2727 - val_accuracy: 0.6996 - val_loss: 0.9047
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5734 - loss: 1.2083 - val_accuracy: 0.6951 - val_loss: 0.9125
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5672 - loss: 1.1955 - val_accuracy: 0.7354 - val_loss: 0.8933
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5601 - loss: 1.2238 - val_accuracy: 0.7489 - val_loss: 0.8719
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5576 - loss: 1.2446 - val_accuracy: 0.7085 - val_loss: 0.8730
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 314s 5s/step - accuracy: 0.5569 - loss: 1.2154 - val_accuracy: 0.7220 - val_loss: 0.8968

# %%
sсores = model.evaluate(test_dataset)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 45s 5s/step - accuracy: 0.7282 - loss: 0.9044

# %%
scores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 scores
#
# NameError: name 'scores' is not defined

# %%
model_version = 2
model.export(f"../models/{model_version}")

# %%
import matplotlib.pyplot as plt

# Assuming 'history' is the output from model.fit()

# Plot accuracy
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np

for images_batch, labels_batch in test_dataset.take(1):
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("First image to predict")
    plt.imshow(first_image)
    plt.axis('off')
    plt.show()
    print("Actual label:", class_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("Predicted label:", class_names[np.argmax(batch_prediction[0])])
# Out:
# First image to predict
# Actual label: Bombay
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# Predicted label: Bombay

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)  

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

plt.figure(figsize = (15,15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis("off")
